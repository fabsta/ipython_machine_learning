# %% [markdown]
# ##Continous supervised learning
#
# ###Continous vs discrete
#
# Choose continous if there is a relationship (order)
# Discrete: individually separate and distinct

# %% [markdown]
# ##Slope and intercept
# Formula
# $$y = m*x+b$$
# m = slope
# b = intercept

# %%
from IPython.display import Image
Image(filename='../images/linear_regression_formula_example.png', width=500)

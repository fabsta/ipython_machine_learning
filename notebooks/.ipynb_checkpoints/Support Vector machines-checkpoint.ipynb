# %% [markdown]
# ##Support vector machines
#
#     x ->      --> Label
#     y -> SVM

# %% [markdown]
# ##Don't work well
# large datasets
# lots of noise (might lead to overfitting)

# %% [markdown]
# ##Non-linear decision surface
# Adding a feature -> making data linearly seperable
# (This is the idea behind the kernel trick)

# %%
from IPython.display import Image
Image(filename='../images/SVM_linearly_seperable.png', width=500)

# %% [markdown]
# ##Kernel-trick
#
# kernel = function that map from low-dimension to high-dimension
# x,y -> X1,X2,X3,X4,X5
# (not separable) -> (separable)

# %% [markdown]
# ##SVM parameters
#
# ###kernel
# Examples
#
# ###C
# tradeoff btw. smooth decision boundary and classifying training points correctly
#
# Classifying all points correctly can -> the SVM not being general enough
# A large C --> expect smooth boundaries
#
# ###Gamma

# %% [markdown]
# ##Overfitting

# %%
#Overfitting
Image(filename='../images/SVM_overfitting.png', width=500)

# %% [markdown]
# Controlled by parameters
# C
# Gamma
# Kernel

# %% [markdown]
# ##Lesson exercise

# %%
#!/usr/bin/python

""" 
    this is the code to accompany the Lesson 2 (SVM) mini-project

    use an SVM to identify emails from the Enron corpus by their authors
    
    Sara has label 0
    Chris has label 1

"""
    
import sys
from time import time
sys.path.append("../tools/")
from email_preprocess import preprocess


### features_train and features_test are the features for the training
### and testing datasets, respectively
### labels_train and labels_test are the corresponding item labels
features_train, features_test, labels_train, labels_test = preprocess()




#########################################################
### your code goes here ###
from sklearn import svm
clf = svm.SVC(kernel='linear')
t0 = time()
print "training time:", round(time()-t0, 3), "s"
clf.fit(features_train, labels_train)  
t0 = time()
#pred = clf.predict(features_test)
print(clf.score(features_test, labels_test))
print "prediction time:", round(time()-t0, 3), "s"


#########################################################

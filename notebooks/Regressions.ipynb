# %%
def studentReg(ages_train, net_worths_train):
    ### import the sklearn regression module, create, and train your regression
    ### name your regression reg
    from sklearn import linear_model
    ### your code goes here!
    
    reg = linear_model.LinearRegression()
    reg.fit(ages_train, net_worths_train)
    return reg

#!/usr/bin/python

import numpy
import matplotlib
matplotlib.use('agg')
# %matplotlib inline

import matplotlib.pyplot as plt
#from studentRegression import studentReg
#from class_vis import prettyPicture, output_image

from ages_net_worths import ageNetWorthData

ages_train, ages_test, net_worths_train, net_worths_test = ageNetWorthData()



reg = studentReg(ages_train, net_worths_train)


plt.clf()
plt.scatter(ages_train, net_worths_train, color="b", label="train data")
plt.scatter(ages_test, net_worths_test, color="r", label="test data")
plt.plot(ages_test, reg.predict(ages_test), color="black")
plt.legend(loc=2)
plt.xlabel("ages")
plt.ylabel("net worths")


#plt.savefig("test.png")
#output_image("test.png", "png", open("test.png", "rb").read())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-156d49019b11> in <module>()
#      20 #from class_vis import prettyPicture, output_image
#      21
# ---> 22 from ages_net_worths import ageNetWorthData
#      23
#      24 ages_train, ages_test, net_worths_train, net_worths_test = ageNetWorthData()
#
# ImportError: No module named ages_net_worths

# %% [markdown]
# ##Score metrics
# R-squared score

# %%
print "Predict 27: ",reg.predict([27]) # should be a list
print "Coeff: ",reg.coef_
print "Intercept",reg.intercept_

print "r-square train: ",reg.score(net_worths_train, ages_train)
print "r-square test: ",reg.score(net_worths_test, ages_test)

# %% [markdown]
# ## Linear regression errors
# ###Minimizing the sum of squared errors (SSE)
#
# error = actual net worth - predicted net worth
#
# ###several algorithm
# odinary least squares (sklearn uses it)
# gradient descent
#
# ###why |error^2|
# there might be several best |error| lines, but only one |error^2|
#
#
# ###SSE isn't perfect
# not enough training points
#
#
# ###R^2
# independent of number of training points
# r^2 : How much of my change in output is explained by change in input
# 0 < r^2 < 1(good)

# %% [markdown]
# #Comparing classification & Regression

# %%
from IPython.display import Image
Image(filename='../images/regression vs classification.png', width=500)

# %% [markdown]
# ##Multivariate regression

# %%
from IPython.display import Image
Image(filename='../images/multivariate_regression.png', width=500)

# %% [markdown]
# # Example project

# %%
import sys
import pickle
sys.path.append("../tools/")
from feature_format import featureFormat, targetFeatureSplit
dictionary = pickle.load( open("../ud120-projects/final_project/final_project_dataset_modified.pkl", "r") )

### list the features you want to look at--first item in the 
### list will be the "target" feature
# stock_options, expenses, salary, 
features_list = ["bonus", "salary"]
data = featureFormat( dictionary, features_list, remove_any_zeroes=True)
target, features = targetFeatureSplit( data )

### training-testing split needed in regression, just like classification
from sklearn.cross_validation import train_test_split
feature_train, feature_test, target_train, target_test = train_test_split(features, target, test_size=0.5, random_state=42)
train_color = "b"
test_color = "r"

import matplotlib
matplotlib.use('agg')
# %matplotlib inline

### your regression goes here!
### please name it reg, so that the plotting code below picks it up and 
### plots it correctly
from sklearn import linear_model
    ### your code goes here!
    
reg = linear_model.LinearRegression()
reg.fit(feature_train, target_train)


plt.clf()
plt.scatter(feature_train, target_train, color="b", label="train data")
plt.scatter(feature_test, target_test, color="r", label="test data")
plt.plot(feature_test, reg.predict(feature_test), color="black")
plt.legend(loc=2)
plt.xlabel("ages")
plt.ylabel("net worths")

print "Coeff: ",reg.coef_[0]
print "Intercept",reg.intercept_

print "r-square train: ",reg.score(feature_train, target_train)
print "r-square test: ",reg.score(feature_test, target_test)
# Out:
# Coeff:  5.44814028881
# Intercept -102360.543294
# r-square train:  0.0455091926995
# r-square test:  -1.48499241737

# %% [markdown]
# Bonus vs long_term regression

# %%
import sys
import pickle
sys.path.append("../tools/")
from feature_format import featureFormat, targetFeatureSplit
dictionary = pickle.load( open("../ud120-projects/final_project/final_project_dataset_modified.pkl", "r") )

### list the features you want to look at--first item in the 
### list will be the "target" feature
# stock_options, expenses, salary, 
features_list = ["bonus", "long_term_incentive"]
data = featureFormat( dictionary, features_list, remove_any_zeroes=True)
target, features = targetFeatureSplit( data )

### training-testing split needed in regression, just like classification
from sklearn.cross_validation import train_test_split
feature_train, feature_test, target_train, target_test = train_test_split(features, target, test_size=0.5, random_state=42)
train_color = "b"
test_color = "r"

import matplotlib
matplotlib.use('agg')
# %matplotlib inline

### your regression goes here!
### please name it reg, so that the plotting code below picks it up and 
### plots it correctly
from sklearn import linear_model
    ### your code goes here!
    
reg = linear_model.LinearRegression()
reg.fit(feature_train, target_train)


plt.clf()
plt.scatter(feature_train, target_train, color="b", label="train data")
plt.scatter(feature_test, target_test, color="r", label="test data")
plt.plot(feature_test, reg.predict(feature_test), color="black")
plt.legend(loc=2)
plt.xlabel("ages")
plt.ylabel("net worths")

print "Coeff: ",reg.coef_[0]
print "Intercept",reg.intercept_

print "r-square train: ",reg.score(feature_train, target_train)
print "r-square test: ",reg.score(feature_test, target_test)
# Out:
# Coeff:  1.19214698985
# Intercept 554478.756215
# r-square train:  0.217085971258
# r-square test:  -0.59271289995

# %%
import sys
import pickle
sys.path.append("../tools/")
from feature_format import featureFormat, targetFeatureSplit
dictionary = pickle.load( open("../ud120-projects/final_project/final_project_dataset_modified.pkl", "r") )

### list the features you want to look at--first item in the 
### list will be the "target" feature
# stock_options, expenses, salary, 
features_list = ["bonus", "salary"]
data = featureFormat( dictionary, features_list, remove_any_zeroes=True)
target, features = targetFeatureSplit( data )

### training-testing split needed in regression, just like classification
from sklearn.cross_validation import train_test_split
feature_train, feature_test, target_train, target_test = train_test_split(features, target, test_size=0.5, random_state=42)
train_color = "b"
test_color = "r"

import matplotlib
matplotlib.use('agg')
# %matplotlib inline

### your regression goes here!
### please name it reg, so that the plotting code below picks it up and 
### plots it correctly
from sklearn import linear_model
    ### your code goes here!
    
reg = linear_model.LinearRegression()
reg.fit(feature_train, target_train)


plt.clf()
plt.scatter(feature_train, target_train, color="b", label="train data")
plt.scatter(feature_test, target_test, color="r", label="test data")
plt.plot(feature_test, reg.predict(feature_test), color="black")
plt.legend(loc=2)
reg.fit(feature_test, target_test)
plt.plot(feature_train, reg.predict(feature_train), color="r") 
plt.xlabel(features_list[-1])
plt.ylabel(features_list[0])

print "Coeff: ",reg.coef_[0]
print "Intercept",reg.intercept_

print "r-square train: ",reg.score(feature_train, target_train)
print "r-square test: ",reg.score(feature_test, target_test)
# Out:
# Coeff:  2.27410114127
# Intercept 124444.388866
# r-square train:  -0.123597985403
# r-square test:  0.251488150398
